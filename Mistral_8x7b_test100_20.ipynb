# %% [markdown]
# <a href="https://colab.research.google.com/github/ZHAOTransparentAI/KICMistral/blob/main/Mistral_8x7b_test100_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # RERUN USING MISTRAL MODEL

# %%
# %cd /content/drive/MyDrive/Hiwi_Job/KICMistral
# Out:
# /content/drive/MyDrive/Hiwi_Job/KICMistral

# %%
# Update the package list
# !sudo apt-get update -y

# Install Python 3.8
# !sudo apt-get install python3.8

# Set Python 3.8 as the default Python version
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# Check the Python version to confirm the change
# !python3 --version

# Install the Python 3.8 distutils package (needed for pip installation)
# !sudo apt-get install python3.8-distutils

# Download the get-pip.py script to install pip
# !wget https://bootstrap.pypa.io/get-pip.py

# Run the script to install pip
# !python3 get-pip.py
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Ign:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,267 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,575 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,030 kB]
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# !python3.8 -m pip install -q scipy==1.7.3 gensim==3.8.3 simplejson==3.17.6 chardet==5.2.0 tqdm==4.66.5
# !python3.8 -m pip install -q huggingface_hub==0.24.6 mistral_common==1.3.4 transformers mistral
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 50.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 47.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.5/715.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 785.0/785.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.4 MB/s eta 0:00:00
# ...

# %%
# !python link_prediction_mistral_8x7b_test_20cans.py --dataset wn18rr --query tail
# Out:
# Start querying the LLM.
# Totally 100 test examples.
# Start PID 3570 and save to ./outputs/wn18rr/output_tail_mistral8x7b_test_20can.txt
#   0% 0/100 [00:00<?, ?it/s]API Response: ChatCompletionOutput(choices=[ChatCompletionOutputComplete(finish_reason='stop', index=0, message=ChatCompletionOutputMessage(role='assistant', content=' Yes. I can assist with link prediction and sorting candidate answers in order of relevance to the goal question.', tool_calls=None), logprobs=None)], created=1726440369, id='', model='mistralai/Mixtral-8x7B-Instruct-v0.1', system_fingerprint='2.2.1-dev0-sha-a4e3e8c', usage=ChatCompletionOutputUsage(completion_tokens=24, prompt_tokens=93, total_tokens=117))
# ...

# %%
# !python link_prediction_mistral_8x7b_test_20cans.py --dataset wn18rr --query tail --align_text
# Out:
# Start querying the LLM.
# Totally 100 test examples.
# Start PID 26359 and save to ./outputs/wn18rr/output_tail_mistral8x7b_test_20can_tsa.txt
#   0% 0/100 [00:00<?, ?it/s]API Response: ChatCompletionOutput(choices=[ChatCompletionOutputComplete(finish_reason='stop', index=0, message=ChatCompletionOutputMessage(role='assistant', content=' Yes. I can assist with link prediction and sorting candidate answers in order of relevance to the goal question.', tool_calls=None), logprobs=None)], created=1726440369, id='', model='mistralai/Mixtral-8x7B-Instruct-v0.1', system_fingerprint='2.2.1-dev0-sha-a4e3e8c', usage=ChatCompletionOutputUsage(completion_tokens=24, prompt_tokens=93, total_tokens=117))
# ...
